# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('telco_churn_encoded.csv')
df.head()
# Out:
#    Gender  Age  Married  Dependents  Number of Dependents  Referred a Friend  \
# 0       1   78        0           0                     0                  0
# 1       0   74        1           1                     0                  1
# 2       1   71        0           1                     0                  0
# 3       0   78        1           1                     0                  1
# 4       0   80        1           1                     0                  1
#
#    Number of Referrals  Tenure in Months  Phone Service  \
# 0                  0.0                 1              0
# 1                  1.0                 8              1
# 2                  0.0                18              1
# 3                  1.0                25              1
# 4                  1.0                37              1
#
#    Avg Monthly Long Distance Charges  ...  Offer_Offer D  Offer_Offer E  \
# 0                               0.00  ...              0              0
# 1                              48.85  ...              0              1
# 2                              11.33  ...              1              0
# 3                              19.76  ...              0              0
# 4                               6.33  ...              0              0
#
#    Internet Type_DSL  Internet Type_Fiber Optic  Internet Type_No Internet  \
# 0                  1                          0                          0
# 1                  0                          1                          0
# 2                  0                          1                          0
# 3                  0                          1                          0
# 4                  0                          1                          0
#
#    Contract_One Year  Contract_Two Year  Payment Method_Credit Card  \
# 0                  0                  0                           0
# 1                  0                  0                           1
# 2                  0                  0                           0
# 3                  0                  0                           0
# 4                  0                  0                           0
#
#    Payment Method_Mailed Check  Churn
# 0                            0      1
# 1                            0      1
# 2                            0      1
# 3                            0      1
# 4                            0      1
#
# [5 rows x 44 columns]

# %%
X_eng = df.drop(columns=['CLTV'], errors='ignore').copy()

# %%
X_eng['charge_per_month'] = X_eng['Total Charges'] / (X_eng['Tenure in Months'] + 1)

# %%
X_eng['is_new_customer'] = (X_eng['Tenure in Months'] < 6).astype(int)

# %%
median_charge = X_eng['Monthly Charge'].median()

X_eng['high_monthly_charge'] = (X_eng['Monthly Charge'] > median_charge).astype(int)

# %%
service_cols = [
    'Online Security',
    'Online Backup',
    'Device Protection Plan',
    'Premium Tech Support',
    'Streaming TV',
    'Streaming Movies',
    'Streaming Music'
]

X_eng['num_services'] = X_eng[service_cols].sum(axis=1)

# %%
from sklearn.model_selection import train_test_split

# target
y = df['Churn']

X_train_eng, X_test_eng, y_train_eng, y_test_eng = train_test_split(
    X_eng,      # your NEW engineered features
    y,          # same target variable
    test_size=0.2,
    random_state=42,
    stratify=y  # VERY IMPORTANT (keeps churn ratio consistent)
)

# %%
final_model.fit(X_train_eng, y_train_eng)

y_pred_final = final_model.predict(X_test_eng)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4730/1060439395.py in <cell line: 0>()
# ----> 1 final_model.fit(X_train_eng, y_train_eng)
#       2
#       3 y_pred_final = final_model.predict(X_test_eng)
#
# NameError: name 'final_model' is not defined
